# %%
import pymysql.cursors
connection = pymysql.connect(host="localhost", 
                     user="root",   
                     passwd="root", 
                     db="comm5940",   
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
        sql = "SELECT * FROM top_attractions"
        cursor.execute(sql)
        result = cursor.fetchall()
        dataset = []
        temp = {}
        i = 0
        for row in result:
            temp[i] = row
            dataset.append(temp[i])
            i = i + 1
        print('\n')
        print(dataset)
        print('\n')
# Out:
# [{'name': 'me', 'location': 'Location', 'attachments': 'Attachments', 'website': 'Website'}, {'name': 'Universal Studios ', 'location': '100 Universal City Plaza, Universal City, CA 91608', 'attachments': '802x535_The_Simpsons_Ride_Exterior.jpg (https://dl.airtable.com/.attachments/411d341858d63b8246c129f09f7a20c0/588ddf4d/802x535_The_Simpsons_Ride_Exterior.jpg),160211_em_themeparks.jpg (https://dl.airtable.com/.attachments/6092ca7f844b30122e9628952bdfe16c/6c02d62d/160211_em_themeparks.jpg),images (1).jpeg (https://dl.airtable.com/.attachments/edb14633c1ad251bd3e6f3212fa44d08/4ddc2506/images1.jpeg),images.jpeg (https://dl.airtable.com/.attachments/a3067a356720b24a434d81cea0ba9177/0d1a6f59/images.jpeg)', 'website': 'http://www.universalstudios.com/'}, {'name': ' Disneyland Resort', 'location': '1313 Disneyland Dr, Anaheim, CA 92802', 'attachments': 'bea72380-83c0-443c-89a0-126c0a1ef27c.jpg (https://dl.airtable.com/.attachments/5567629f7f47b110099d3a2803ec3b9c/5b55f412/bea72380-83c0-44
# ...

# %%
import requests

headers = {
'Authorization': 'Bearer keye05BAfKTbqK2DZ',
}

params = (
('view', 'Grid view'),
)

r = requests.get('https://api.airtable.com/v0/appBfxREizUvUlYSG/Top%20Attractions?api_key=keye05BAfKTbqK2DZ', headers=headers, params=params)
dict = r.json()
dataset = []
Name = []
Location = []
Attachments = []
Website = []

for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
for dicts in dataset:
    name.append(dicts.get('name'))
    location.append(dicts.get('location'))
    attachments.append(dicts.get('attachments'))
    website.append(dicts.get('website'))
print(Name)
# Out:
# [{'Name': 'Universal Studios ', 'Location': '100 Universal City Plaza, Universal City, CA 91608', 'Attachments': [{'id': 'attidEGL8ga0LAqtc', 'url': 'https://dl.airtable.com/.attachments/411d341858d63b8246c129f09f7a20c0/588ddf4d/802x535_The_Simpsons_Ride_Exterior.jpg', 'filename': '802x535_The_Simpsons_Ride_Exterior.jpg', 'size': 267608, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/f15d95322cb1e394bfa49ea7f8176a3d/a4505e58', 'width': 54, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/444bec05feeb1b251848c71b2d0d35d7/3b7d82f1', 'width': 768, 'height': 512}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/6d2178d5f78a68f6747685fba3e9e81b/6f068d56', 'width': 3000, 'height': 3000}}}, {'id': 'attlqqY5XRTfrEXn5', 'url': 'https://dl.airtable.com/.attachments/6092ca7f844b30122e9628952bdfe16c/6c02d62d/160211_em_themeparks.jpg', 'filename': '160211_em_themeparks.jpg', 'size': 2178234, 'type':
# ...
